# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/euzoe/OneDrive/Desktop/REPATH/Unicorn_Companies.csv')

# %%
df.head(15)
# Out:
#          Company Valuation ($B) Date Joined         Country           City  \
# 0      Bytedance           $140    4/7/2017           China        Beijing
# 1         SpaceX         $100.3   12/1/2012   United States      Hawthorne
# 2         Stripe            $95   1/23/2014   United States  San Francisco
# 3         Klarna          $45.6  12/12/2011          Sweden      Stockholm
# 4     Epic Games            $42  10/26/2018   United States           Cary
# 5          Canva            $40    1/8/2018       Australia    Surry Hills
# 6   Checkout.com            $40    5/2/2019  United Kingdom         London
# 7      Instacart            $39  12/30/2014   United States  San Francisco
# 8     Databricks            $38    2/5/2019   United States  San Francisco
# 9        Revolut            $33   4/26/2018  United Kingdom         London
# 10           FTX            $32   7/20/2021         Bahamas        Fintech
# ...

# %% [markdown]
# # DATA CLEANING AND PREPARATION

# %%
df['Valuation ($B)']=df['Valuation ($B)'].str.replace('$', '').astype(float)
df['Date Joined']=pd.to_datetime(df['Date Joined'])
# Out:
# C:\Users\euzoe\AppData\Local\Temp/ipykernel_7004/3964259185.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Valuation ($B)']=df['Valuation ($B)'].str.replace('$', '').astype(float)

# %%
df.head()
# Out:
#       Company  Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           140.0  2017-04-07          China        Beijing
# 1      SpaceX           100.3  2012-12-01  United States      Hawthorne
# 2      Stripe            95.0  2014-01-23  United States  San Francisco
# 3      Klarna            45.6  2011-12-12         Sweden      Stockholm
# 4  Epic Games            42.0  2018-10-26  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
df.columns=df.columns.str.replace(' ', '_')

# %%
df.head()
# Out:
#       Company  Valuation_($B) Date_Joined        Country           City  \
# 0   Bytedance           140.0  2017-04-07          China        Beijing
# 1      SpaceX           100.3  2012-12-01  United States      Hawthorne
# 2      Stripe            95.0  2014-01-23  United States  San Francisco
# 3      Klarna            45.6  2011-12-12         Sweden      Stockholm
# 4  Epic Games            42.0  2018-10-26  United States           Cary
#
#                   Industry                                  Select_Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
df.isnull().sum()
# Out:
# Company              0
# Valuation_($B)       0
# Date_Joined          0
# Country              0
# City                 0
# Industry             0
# Select_Inverstors    0
# Founded_Year         0
# Total_Raised         0
# Financial_Stage      0
# Investors_Count      0
# Deal_Terms           0
# Portfolio_Exits      0
# dtype: int64

# %% [markdown]
# # To save the cleaned data as CSV
#
# df.to_csv('unicorn_companies.csv')

# %%
knowpyth_ger=(df['Country']=='China')

# %% [markdown]
# # Check the number of times a particular investor appears in each company

# %%
df.loc[df['Select_Inverstors'].str.contains('Accel')].count()
# Out:
# Company              65
# Valuation_($B)       65
# Date_Joined          65
# Country              65
# City                 65
# Industry             65
# Select_Inverstors    65
# Founded_Year         65
# Total_Raised         65
# Financial_Stage      65
# Investors_Count      65
# Deal_Terms           65
# Portfolio_Exits      65
# dtype: int64

# %%
df.Select_Inverstors.nunique()
# Out:
# 1006
